# %% [markdown]
# # CRM Analysis DATASET

# %% [markdown]
# The table shows a list of opportunities with the following columns:
# 1)
# opportunity_id: Unique identifier for the opportuni. t
# 2) y
# sales_agent: Name of the sales agent associated with the opportun.  i
# 3) ty
# product: Name of the product being . s
# 4) old
# account: Name of the company or cus. t
# 5) omer
# deal_stage: Current stage of the sales p. r
# 6) ocess
# engage_date: Date when the opportunity was first . e
# 7) ngaged
# close_date: Date when the opportunity wa. s
# 8)   closed
# close_value: Value of the opportunity a. t closing

# %% [markdown]
# # Import usefull python library

# %%
import warnings
warnings.filterwarnings("ignore")
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.io as pio
sns.set_theme(style="darkgrid")

# %%
link="C:\\Users\\rites\\Downloads\\sales_pipeline.csv"
sp= pd.read_csv(link)

# %% [markdown]
# # checking the top 10 columns of the dataset

# %%
sp.head()
# Out:
#   opportunity_id      sales_agent         product  account deal_stage  \
# 0       1C1I7A6R      Moses Frase  GTX Plus Basic  Cancity        Won
# 1       Z063OYW0  Darcel Schlecht          GTXPro    Isdom        Won
# 2       EC4QE1BX  Darcel Schlecht      MG Special  Cancity        Won
# 3       MV1LWRNH      Moses Frase       GTX Basic  Codehow        Won
# 4       PE84CX4O        Zane Levy       GTX Basic   Hatfan        Won
#
#   engage_date  close_date  close_value
# 0  2016-10-20  2017-03-01       1054.0
# 1  2016-10-25  2017-03-11       4514.0
# 2  2016-10-25  2017-03-07         50.0
# 3  2016-10-25  2017-03-09        588.0
# 4  2016-10-25  2017-03-02        517.0

# %% [markdown]
# # checking the bottom 10 columns of the dataset

# %%
sp.tail()
# Out:
#      opportunity_id        sales_agent      product account   deal_stage  \
# 8795       9MIWFW5J  Versie Hillebrand  MG Advanced     NaN  Prospecting
# 8796       6SLKZ8FI  Versie Hillebrand  MG Advanced     NaN  Prospecting
# 8797       LIB4KUZJ  Versie Hillebrand  MG Advanced     NaN  Prospecting
# 8798       18IUIUK0  Versie Hillebrand  MG Advanced     NaN  Prospecting
# 8799       8I5ONXJX  Versie Hillebrand  MG Advanced     NaN  Prospecting
#
#      engage_date close_date  close_value
# 8795         NaN        NaN          NaN
# 8796         NaN        NaN          NaN
# 8797         NaN        NaN          NaN
# 8798         NaN        NaN          NaN
# 8799         NaN        NaN          NaN

# %% [markdown]
# # checking the shape of the dataset

# %%
sp.shape
# Out:
# (8800, 8)

# %% [markdown]
# # checking the column name of the dataset

# %%
sp.columns
# Out:
# Index(['opportunity_id', 'sales_agent', 'product', 'account', 'deal_stage',
#        'engage_date', 'close_date', 'close_value'],
#       dtype='object')

# %% [markdown]
# # show the type dataset

# %%
print(type(sp))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# # show the null column

# %%
sp.isna().sum()
# Out:
# opportunity_id       0
# sales_agent          0
# product              0
# account           1425
# deal_stage           0
# engage_date        500
# close_date        2089
# close_value       2089
# dtype: int64

# %% [markdown]
# # show information of the datset

# %%
sp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8800 entries, 0 to 8799
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   opportunity_id  8800 non-null   object
#  1   sales_agent     8800 non-null   object
#  2   product         8800 non-null   object
#  3   account         7375 non-null   object
#  4   deal_stage      8800 non-null   object
#  5   engage_date     8300 non-null   object
#  6   close_date      6711 non-null   object
#  7   close_value     6711 non-null   float64
# dtypes: float64(1), object(7)
# memory usage: 550.1+ KB

# %% [markdown]
# # check statistical function

# %%
sp.describe()
# Out:
#         close_value
# count   6711.000000
# mean    1490.915512
# std     2320.670773
# min        0.000000
# 25%        0.000000
# 50%      472.000000
# 75%     3225.000000
# max    30288.000000

# %% [markdown]
# # --------------------------------------DATA CLEANING---------------------------------

# %%
sp.isna().sum()
# Out:
# opportunity_id       0
# sales_agent          0
# product              0
# account           1425
# deal_stage           0
# engage_date        500
# close_date        2089
# close_value       2089
# dtype: int64

# %% [markdown]
# # ====================================================
# # Insights
# There are four  columns that have Null values .so I'm going to clean four cloumns
# # ====================================================

# %% [markdown]
# # check the percentage of null value column

# %%
x=sp.isna().sum()
x=dict(x)
for i,j in x.items():
    print(i,round(j/8800*100,2))
# Out:
# opportunity_id 0.0
# sales_agent 0.0
# product 0.0
# account 16.19
# deal_stage 0.0
# engage_date 5.68
# close_date 23.74
# close_value 23.74

# %%
sp.head()
# Out:
#   opportunity_id      sales_agent         product  account deal_stage  \
# 0       1C1I7A6R      Moses Frase  GTX Plus Basic  Cancity        Won
# 1       Z063OYW0  Darcel Schlecht          GTXPro    Isdom        Won
# 2       EC4QE1BX  Darcel Schlecht      MG Special  Cancity        Won
# 3       MV1LWRNH      Moses Frase       GTX Basic  Codehow        Won
# 4       PE84CX4O        Zane Levy       GTX Basic   Hatfan        Won
#
#   engage_date  close_date  close_value
# 0  2016-10-20  2017-03-01       1054.0
# 1  2016-10-25  2017-03-11       4514.0
# 2  2016-10-25  2017-03-07         50.0
# 3  2016-10-25  2017-03-09        588.0
# 4  2016-10-25  2017-03-02        517.0

# %% [markdown]
# # fill the  account column

# %%
# data type of account column
sp["account"].dtype
# Out:
# dtype('O')

# %%
x=sp["account"].mode()
x
# Out:
# 0    Hottechi
# Name: account, dtype: object

# %%
sp["account"].fillna(x[0],inplace=True)

# %%
sp["account"].isna().sum()
# Out:
# 0

# %%
sp.head()
# Out:
#   opportunity_id      sales_agent         product  account deal_stage  \
# 0       1C1I7A6R      Moses Frase  GTX Plus Basic  Cancity        Won
# 1       Z063OYW0  Darcel Schlecht          GTXPro    Isdom        Won
# 2       EC4QE1BX  Darcel Schlecht      MG Special  Cancity        Won
# 3       MV1LWRNH      Moses Frase       GTX Basic  Codehow        Won
# 4       PE84CX4O        Zane Levy       GTX Basic   Hatfan        Won
#
#   engage_date  close_date  close_value
# 0  2016-10-20  2017-03-01       1054.0
# 1  2016-10-25  2017-03-11       4514.0
# 2  2016-10-25  2017-03-07         50.0
# 3  2016-10-25  2017-03-09        588.0
# 4  2016-10-25  2017-03-02        517.0

# %%
sp.tail()
# Out:
#      opportunity_id        sales_agent      product   account   deal_stage  \
# 8795       9MIWFW5J  Versie Hillebrand  MG Advanced  Hottechi  Prospecting
# 8796       6SLKZ8FI  Versie Hillebrand  MG Advanced  Hottechi  Prospecting
# 8797       LIB4KUZJ  Versie Hillebrand  MG Advanced  Hottechi  Prospecting
# 8798       18IUIUK0  Versie Hillebrand  MG Advanced  Hottechi  Prospecting
# 8799       8I5ONXJX  Versie Hillebrand  MG Advanced  Hottechi  Prospecting
#
#      engage_date close_date  close_value
# 8795         NaN        NaN          NaN
# 8796         NaN        NaN          NaN
# 8797         NaN        NaN          NaN
# 8798         NaN        NaN          NaN
# 8799         NaN        NaN          NaN

# %% [markdown]
# # fill the engage_date column

# %%
sp["engage_date"].dtype
# Out:
# dtype('O')

# %%
x =sp["engage_date"].mode()
x
# Out:
# 0    2017-07-22
# Name: engage_date, dtype: object

# %%
sp["engage_date"].fillna(x[0],inplace=True)

# %%
sp["engage_date"].isna().sum()
# Out:
# 0

# %%
sp.head()
# Out:
#   opportunity_id      sales_agent         product  account deal_stage  \
# 0       1C1I7A6R      Moses Frase  GTX Plus Basic  Cancity        Won
# 1       Z063OYW0  Darcel Schlecht          GTXPro    Isdom        Won
# 2       EC4QE1BX  Darcel Schlecht      MG Special  Cancity        Won
# 3       MV1LWRNH      Moses Frase       GTX Basic  Codehow        Won
# 4       PE84CX4O        Zane Levy       GTX Basic   Hatfan        Won
#
#   engage_date  close_date  close_value
# 0  2016-10-20  2017-03-01       1054.0
# 1  2016-10-25  2017-03-11       4514.0
# 2  2016-10-25  2017-03-07         50.0
# 3  2016-10-25  2017-03-09        588.0
# 4  2016-10-25  2017-03-02        517.0

# %%
sp.tail()
# Out:
#      opportunity_id        sales_agent      product   account   deal_stage  \
# 8795       9MIWFW5J  Versie Hillebrand  MG Advanced  Hottechi  Prospecting
# 8796       6SLKZ8FI  Versie Hillebrand  MG Advanced  Hottechi  Prospecting
# 8797       LIB4KUZJ  Versie Hillebrand  MG Advanced  Hottechi  Prospecting
# 8798       18IUIUK0  Versie Hillebrand  MG Advanced  Hottechi  Prospecting
# 8799       8I5ONXJX  Versie Hillebrand  MG Advanced  Hottechi  Prospecting
#
#      engage_date close_date  close_value
# 8795  2017-07-22        NaN          NaN
# 8796  2017-07-22        NaN          NaN
# 8797  2017-07-22        NaN          NaN
# 8798  2017-07-22        NaN          NaN
# 8799  2017-07-22        NaN          NaN

# %% [markdown]
# # fill the close_date column

# %%
sp["close_date"].dtype
# Out:
# dtype('O')

# %%
x=sp["close_date"].mode()
x
# Out:
# 0    2017-05-22
# Name: close_date, dtype: object

# %%
sp["close_date"].fillna(x[0],inplace=True)

# %%
sp["close_date"].isna().sum()
# Out:
# 0

# %%
sp.head()
# Out:
#   opportunity_id      sales_agent         product  account deal_stage  \
# 0       1C1I7A6R      Moses Frase  GTX Plus Basic  Cancity        Won
# 1       Z063OYW0  Darcel Schlecht          GTXPro    Isdom        Won
# 2       EC4QE1BX  Darcel Schlecht      MG Special  Cancity        Won
# 3       MV1LWRNH      Moses Frase       GTX Basic  Codehow        Won
# 4       PE84CX4O        Zane Levy       GTX Basic   Hatfan        Won
#
#   engage_date  close_date  close_value
# 0  2016-10-20  2017-03-01       1054.0
# 1  2016-10-25  2017-03-11       4514.0
# 2  2016-10-25  2017-03-07         50.0
# 3  2016-10-25  2017-03-09        588.0
# 4  2016-10-25  2017-03-02        517.0

# %%
sp.tail()
# Out:
#      opportunity_id        sales_agent      product   account   deal_stage  \
# 8795       9MIWFW5J  Versie Hillebrand  MG Advanced  Hottechi  Prospecting
# 8796       6SLKZ8FI  Versie Hillebrand  MG Advanced  Hottechi  Prospecting
# 8797       LIB4KUZJ  Versie Hillebrand  MG Advanced  Hottechi  Prospecting
# 8798       18IUIUK0  Versie Hillebrand  MG Advanced  Hottechi  Prospecting
# 8799       8I5ONXJX  Versie Hillebrand  MG Advanced  Hottechi  Prospecting
#
#      engage_date  close_date  close_value
# 8795  2017-07-22  2017-05-22          NaN
# 8796  2017-07-22  2017-05-22          NaN
# 8797  2017-07-22  2017-05-22          NaN
# 8798  2017-07-22  2017-05-22          NaN
# 8799  2017-07-22  2017-05-22          NaN

# %% [markdown]
# # fill the data  of close value column

# %%
sp["close_value"].dtype
# Out:
# dtype('float64')

# %%
M=sp["close_value"].mean()
M
# Out:
# 1490.9155118462227

# %%
sp["close_value"].median()
# Out:
# 472.0

# %%
sp["close_value"].fillna(M,inplace=True)

# %%
sp["close_value"].isna().sum()
# Out:
# 0

# %%
sp.head()
# Out:
#   opportunity_id      sales_agent         product  account deal_stage  \
# 0       1C1I7A6R      Moses Frase  GTX Plus Basic  Cancity        Won
# 1       Z063OYW0  Darcel Schlecht          GTXPro    Isdom        Won
# 2       EC4QE1BX  Darcel Schlecht      MG Special  Cancity        Won
# 3       MV1LWRNH      Moses Frase       GTX Basic  Codehow        Won
# 4       PE84CX4O        Zane Levy       GTX Basic   Hatfan        Won
#
#   engage_date  close_date  close_value
# 0  2016-10-20  2017-03-01       1054.0
# 1  2016-10-25  2017-03-11       4514.0
# 2  2016-10-25  2017-03-07         50.0
# 3  2016-10-25  2017-03-09        588.0
# 4  2016-10-25  2017-03-02        517.0

# %%
sp.tail()
# Out:
#      opportunity_id        sales_agent      product   account   deal_stage  \
# 8795       9MIWFW5J  Versie Hillebrand  MG Advanced  Hottechi  Prospecting
# 8796       6SLKZ8FI  Versie Hillebrand  MG Advanced  Hottechi  Prospecting
# 8797       LIB4KUZJ  Versie Hillebrand  MG Advanced  Hottechi  Prospecting
# 8798       18IUIUK0  Versie Hillebrand  MG Advanced  Hottechi  Prospecting
# 8799       8I5ONXJX  Versie Hillebrand  MG Advanced  Hottechi  Prospecting
#
#      engage_date  close_date  close_value
# 8795  2017-07-22  2017-05-22  1490.915512
# 8796  2017-07-22  2017-05-22  1490.915512
# 8797  2017-07-22  2017-05-22  1490.915512
# 8798  2017-07-22  2017-05-22  1490.915512
# 8799  2017-07-22  2017-05-22  1490.915512

# %% [markdown]
# # ========================DONE================

# %% [markdown]
# # -------------------------------------DATA VISUALIZATION ----------------------------------------------------

# %% [markdown]
# # change the engage_date column name to starting_data

# %%
x=sp.rename(columns={"engage_date":"starting_date"},inplace=True)
x

# %%
sp.head()
# Out:
#   opportunity_id      sales_agent         product  account deal_stage  \
# 0       1C1I7A6R      Moses Frase  GTX Plus Basic  Cancity        Won
# 1       Z063OYW0  Darcel Schlecht          GTXPro    Isdom        Won
# 2       EC4QE1BX  Darcel Schlecht      MG Special  Cancity        Won
# 3       MV1LWRNH      Moses Frase       GTX Basic  Codehow        Won
# 4       PE84CX4O        Zane Levy       GTX Basic   Hatfan        Won
#
#   starting_date  close_date  close_value
# 0    2016-10-20  2017-03-01       1054.0
# 1    2016-10-25  2017-03-11       4514.0
# 2    2016-10-25  2017-03-07         50.0
# 3    2016-10-25  2017-03-09        588.0
# 4    2016-10-25  2017-03-02        517.0

# %% [markdown]
# # 1. we are finding the sales_agent to close_value on CRM

# %%
# check the unique name of sales_agent
sp["sales_agent"].unique()
# Out:
# array(['Moses Frase', 'Darcel Schlecht', 'Zane Levy', 'Anna Snelling',
#        'Vicki Laflamme', 'Markita Hansen', 'Niesha Huffines',
#        'James Ascencio', 'Gladys Colclough', 'Maureen Marcano',
#        'Hayden Neloms', 'Rosalina Dieter', 'Versie Hillebrand',
#        'Daniell Hammack', 'Elease Gluck', 'Violet Mclelland',
#        'Kami Bicknell', 'Rosie Papadopoulos', 'Kary Hendrixson',
#        'Reed Clapper', 'Wilburn Farren', 'Garret Kinder',
#        'Marty Freudenburg', 'Cassey Cress', 'Lajuana Vencill',
#        'Boris Faz', 'Donn Cantrell', 'Corliss Cosme', 'Cecily Lampkin',
#        'Jonathan Berthelot'], dtype=object)

# %%
# 1.1 find the total close_value by sales_agent and create a bar graph
x=sp.groupby("sales_agent")["close_value"].sum().reset_index()
x =x.sort_values("close_value",ascending=False)
x.head(10)
# Out:
#          sales_agent   close_value
# 6    Darcel Schlecht  1.442452e+06
# 26    Vicki Laflamme  6.334512e+05
# 15   Kary Hendrixson  6.078623e+05
# 2       Cassey Cress  5.772168e+05
# 29         Zane Levy  5.612686e+05
# 4      Corliss Cosme  5.418002e+05
# 12    James Ascencio  5.044788e+05
# 10  Gladys Colclough  4.724018e+05
# 5    Daniell Hammack  4.715749e+05
# 19   Maureen Marcano  4.577409e+05

# %%
plt.figure(figsize=(20,5))
sns.barplot(data=x,x="sales_agent",y="close_value",palette="autumn")
plt.xticks(rotation=45)
plt.title("Total close value by sales agent",fontweight="bold",fontsize=20,color="red")
plt.show()

# %% [markdown]
# # Insights:-
#  The barplot  shows the total close value by sales agent:-
#  1. The sales agent Darcel Schlecht has the highest close value .
#  2. The sales agent Garret Kinder has the lowest close value .

# %% [markdown]
# #1.2find the top 10 sales agent  and bottom 10 sales agent by close value on CRM?

# %%
plt.figure(figsize=(20,5))
plt.subplot(1,2,1)
sns.barplot(data=x.head(10),x="sales_agent",y="close_value")
plt.title("TOP 10 SALES AGENT ON SALES PIPELINE",fontweight="bold",color="blue")
plt.xticks(rotation=45)
plt.subplot(1,2,2)
sns.barplot(data=x.tail(10),x="sales_agent",y="close_value")
plt.title("BOTTOM 10 SALES AGENT ON SALES PIPELINE",fontweight="bold",color="blue")
plt.suptitle("SUM OF CLOSE VALUE BY SALES AGENT",fontweight="bold",fontsize=20)
plt.xticks(rotation=30)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # Insights :
#  Top 10}
# 1) With the help of this Barplot we analyse that the sales agent Darcel Schlechte is highest colse value  on CRM.
#
#  Bottom 10}
# 1) with the help of this  Barplot i can see that Versie Hillebrand is lowest close value on CRM it is the big Insights from the data.

# %% [markdown]
# # 2.Find out the product to close_value on CRM

# %%
# show the total number of close value by product
x=sp.groupby("product")["close_value"].sum().reset_index()
x
# Out:
#           product   close_value
# 0         GTK 500  4.229757e+05
# 1       GTX Basic  1.140357e+06
# 2  GTX Plus Basic  1.200259e+06
# 3    GTX Plus Pro  2.962125e+06
# 4          GTXPro  4.007053e+06
# 5     MG Advanced  2.705407e+06
# 6      MG Special  6.818798e+05

# %%
# show the average number of close value by product
y=sp.groupby("product")["close_value"].mean().reset_index()
y
# Out:
#           product   close_value
# 0         GTK 500  10574.393317
# 1       GTX Basic    611.123617
# 2  GTX Plus Basic    867.866197
# 3    GTX Plus Pro   3060.046652
# 4          GTXPro   2707.468152
# 5     MG Advanced   1916.010827
# 6      MG Special    413.010199

# %%
plt.figure(figsize=(20,7))
plt.subplot(1,2,1)
sns.barplot(data=x,x="product",y="close_value",color="red")
plt.title("Total close value by product",fontweight="bold",fontsize=20)
plt.xticks(rotation=65)
plt.subplot(1,2,2)
sns.lineplot(data=y,x="product",y="close_value",color="green")
plt.title("Average close value by product",fontweight="bold",fontsize=20)
plt.xticks(rotation=65)
plt.suptitle("SUM OF CLOSE VALUE BY PRODUCT",fontweight="bold",fontsize=25,color="black")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # Insights:-
#  The barplot show total close value by product :-
#   1. The product GTXPro has the highest close value .
#   2. The product GTK500  has the lowest close value .
#
#  The lineplot show average close value by product :-
#   1. The product GTK500 has the highest average close value .
#   2. The product MG Special has the lowest average close value.

# %%
#crate a pie chart and show the maximum close value by product?
a =sp.groupby("product")["close_value"].max().reset_index()
a=a.sort_values("close_value",ascending=False)
a
# Out:
#           product   close_value
# 0         GTK 500  30288.000000
# 3    GTX Plus Pro   7356.000000
# 4          GTXPro   6166.000000
# 5     MG Advanced   4456.000000
# 1       GTX Basic   1490.915512
# 2  GTX Plus Basic   1490.915512
# 6      MG Special   1490.915512

# %%
plt.figure(figsize=(10,4))
sns.lineplot(data=a,x="product",y="close_value",color="blue")
plt.title("Total close value by product",fontweight="bold",fontsize=20)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# #####

# %% [markdown]
# #

# %% [markdown]
# # Insights:-
#  The lineplot that shows Total close value by product :-
# 1)  The product  GTK 500 having the highest close value on CRM.
# 2)  The product MG Special having the lowest close value on CRM.

# %% [markdown]
# # 3.Find out the Account to close_value on CRM

# %%
# find the total account by close value on CRM?
x=sp.groupby("account")["close_value"].sum().reset_index()
x=x.sort_values("close_value",ascending=False)
x
# Out:
#           account   close_value
# 34       Hottechi  2.329948e+06
# 40       Kan-code  3.548732e+05
# 42          Konex  2.796814e+05
# 11         Condax  2.228101e+05
# 9          Cheers  2.099473e+05
# ..            ...           ...
# 67         Sumace  7.630507e+04
# 6   Bluth Company  7.330307e+04
# 79     Zathunicon  6.605241e+04
# 18        Donware  6.110975e+04
# 29        Golddex  6.057749e+04
#
# [85 rows x 2 columns]

# %%
plt.figure(figsize=(15,3))
sns.barplot(data=x.head(40),x="account",y="close_value",palette="rainbow")
plt.title("Sum of close value by account",fontweight="bold",fontsize=20,color="blue")
plt.xticks(rotation=75)
plt.show()

# %% [markdown]
# # insights:-
#  The barplot that shows the sum of close value by account:-
#  1) The visualization shows the top 40 accounts with the highest sum of close values.
#  2)  The account 'Hottechi' has the highest close value, with over 2 million.
#  3)  The accounts 'Kan-code', 'Konex', and 'Condax' have close values between 1 and 2 million.
#  4)  The remaining accounts have close values below 1 million.

# %%
# find the top 5 account  and bottom 5 bottom by close value on CRM?
x=sp.groupby("account")["close_value"].sum().reset_index()
x=x.sort_values("close_value",ascending=True).head()
x
# Out:
#           account   close_value
# 29        Golddex  60577.493071
# 18        Donware  61109.746536
# 79     Zathunicon  66052.408583
# 6   Bluth Company  73303.070630
# 67         Sumace  76305.070630

# %%
y=sp.groupby("account")["close_value"].sum().reset_index()
y=y.sort_values("close_value",ascending=True).tail()
y
# Out:
#      account   close_value
# 9     Cheers  2.099473e+05
# 11    Condax  2.228101e+05
# 42     Konex  2.796814e+05
# 40  Kan-code  3.548732e+05
# 34  Hottechi  2.329948e+06

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
plt.pie(x["close_value"],labels=x["account"],radius=1,shadow=True,autopct="%0.2f%%",explode=[0,0,0,0,0.1])
plt.pie([1],colors=['w'],radius=0.4)
plt.title("Top Five Account",color="black")
plt.subplot(1,2,2)
plt.pie(y["close_value"],labels=y["account"],radius=1,shadow=True,autopct="%0.2f%%",explode=[0,0,0,0,0.1])
plt.pie([1],colors=['w'],radius=0.4)
plt.title("Bottom Five Account",color="black")
plt.suptitle("Sum of close value by account",fontweight="bold",color="black",fontsize=18)
plt.show()

# %% [markdown]
# # Insights:-
#   The donut chart show total Close value by account on CRM:-
#
#    Top 5}
# 1) With the help of this donut chart we analyse that the account Sumace is highest colse value  on CRM.
#
#  Bottom 5}
# 1) with the help of this  Barplot i can see that Hottechi is lowest close value on CRM it is the big Insights from the data.

# %%
# 3.2:-count the total account on CRM?
x=sp['account'].nunique()
x
# Out:
# 85

# %%
plt.figure(figsize=(15,4))
sns.histplot(data=sp.head(40),x="account",color="orange")
plt.title(" count the account on CRM ",fontweight="bold",fontsize=20)
plt.xticks(rotation=75)
plt.show()

# %% [markdown]
# # Insights:-
# 1) The histogram shows the distribution of accounts on the CRM.
# Each bar represents a different account, and the height of the bar
# indicates the number of times that account appears in the data.
# 2) The visualization shows that some accounts appear more frequently
# than others on the CRM :-
# 3) For example:- accounts like Cancity, Ron-tech, Cheers,Zumgoity,etc have
# the highest count, while accounts like Isdom, Codehow,Hatfan ,etc
#  have the lowest count.
# 4) This information could be useful for identifying which accounts are
# most active on the CRM and for understanding the overall distribution of accounts.

# %%
#count the type of deal stage on CRM
x=sp['deal_stage'].value_counts()
keys=x.keys()
val=x.values

# %%
plt.figure(figsize=(5,5))
plt.pie(val,labels=keys,autopct="%0.2f%%",explode=[0,0,0,0.2])
plt.pie([1],colors=['w'],radius=0.4)
plt.title("Count the total deal stage on CRM",fontweight="bold",fontsize=20)
plt.show()

# %% [markdown]
#  # Insights:-
#   The donut chart show total deal stage on CRM:-
# 1) 48.16% of deals are in the Won stage.
# 2) 28.10% of deals are in the Lost stage.
# 3) 18.06% of deals are in the Engaging stage.
# 4) 5.68% of deals are in the Prospecting stage.
#
# This visual representation allows a user to easily understand the distribution
# of deals across the CRM and identify areas where improvements could
# be made.For instance, the high percentage of lost deals may indicate a need to
# revisit lead qualification or sales processes.

# %% [markdown]
# # ------------------------------------------------------------------------------------------------------------ENDING-----------------------------------------------------------------------------------
